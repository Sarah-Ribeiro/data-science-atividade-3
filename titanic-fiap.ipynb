# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sarahribeiro/Library/Python/3.12/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
dados = pd.read_csv('titanic-fiap.csv')

# %%
dados.fillna(0, inplace=True)

dados.drop(columns=['PassengerId'], inplace=True)

# %%
dados.index.name= 'PassengerId'

# %%
dados.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
print('Mediana de idade dos passageiros ->',dados.Age.median())
print('Média de idade dos passageiros ->',dados.Age.mean().round(2))
# Out:
# Mediana de idade dos passageiros -> 24.0
# Média de idade dos passageiros -> 23.8

# %%
dados.Age.describe()
# Out:
# count    891.000000
# mean      23.799293
# std       17.596074
# min        0.000000
# 25%        6.000000
# 50%       24.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
dados
# Out:
#              Survived  Pclass  \
# PassengerId
# 0                   0       3
# 1                   1       1
# 2                   1       3
# 3                   1       1
# 4                   0       3
# ...               ...     ...
# 886                 0       2
# 887                 1       1
# 888                 0       3
# 889                 1       1
# 890                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 0                                      Braund, Mr. Owen Harris    male  22.0
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                                       Heikkinen, Miss. Laina  female  26.0
# 3                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 886                                      Montvila, Rev. Juozas    male  27.0
# 887                               Graham, Miss. Margaret Edith  female  19.0
# 888                   Johnston, Miss. Catherine Helen "Carrie"  female   0.0
# 889                                      Behr, Mr. Karl Howell    male  26.0
# 890                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 0                1      0         A/5 21171   7.2500     0        S
# 1                1      0          PC 17599  71.2833   C85        C
# 2                0      0  STON/O2. 3101282   7.9250     0        S
# 3                1      0            113803  53.1000  C123        S
# 4                0      0            373450   8.0500     0        S
# ...            ...    ...               ...      ...   ...      ...
# 886              0      0            211536  13.0000     0        S
# 887              0      0            112053  30.0000   B42        S
# 888              1      2        W./C. 6607  23.4500     0        S
# 889              0      0            111369  30.0000  C148        C
# 890              0      0            370376   7.7500     0        Q
#
# [891 rows x 11 columns]

# %%
dados.Survived.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
dados.Pclass.value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
dados.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# 0      2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Set the global default size of matplotlib figures
plt.rc('figure', figsize=(10, 5))

# Size of matplotlib figures that contain subplots
fizsize_with_subplots = (10, 10)

# Size of matplotlib histogram bins
bin_size = 10

# %%
southampton = dados['Embarked'] == 'S'
cherbourg  = dados['Embarked'] == 'C'
queenstown = dados['Embarked'] == 'Q'

dados.loc[southampton, 'Embarked'] = 'S = Southampton'
dados.loc[queenstown, 'Embarked'] = 'Q = Queenstown'
dados.loc[cherbourg, 'Embarked'] = 'C = Cherbourg'

# %%
dados.Embarked.value_counts()
# Out:
# Embarked
# S = Southampton    644
# C = Cherbourg      168
# Q = Queenstown      77
# 0                    2
# Name: count, dtype: int64

# %%
dados
# Out:
#              Survived  Pclass  \
# PassengerId
# 0                   0       3
# 1                   1       1
# 2                   1       3
# 3                   1       1
# 4                   0       3
# ...               ...     ...
# 886                 0       2
# 887                 1       1
# 888                 0       3
# 889                 1       1
# 890                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 0                                      Braund, Mr. Owen Harris    male  22.0
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                                       Heikkinen, Miss. Laina  female  26.0
# 3                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 886                                      Montvila, Rev. Juozas    male  27.0
# 887                               Graham, Miss. Margaret Edith  female  19.0
# 888                   Johnston, Miss. Catherine Helen "Carrie"  female   0.0
# 889                                      Behr, Mr. Karl Howell    male  26.0
# 890                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin         Embarked
# PassengerId
# 0                1      0         A/5 21171   7.2500     0  S = Southampton
# 1                1      0          PC 17599  71.2833   C85    C = Cherbourg
# 2                0      0  STON/O2. 3101282   7.9250     0  S = Southampton
# 3                1      0            113803  53.1000  C123  S = Southampton
# 4                0      0            373450   8.0500     0  S = Southampton
# ...            ...    ...               ...      ...   ...              ...
# 886              0      0            211536  13.0000     0  S = Southampton
# 887              0      0            112053  30.0000   B42  S = Southampton
# 888              1      2        W./C. 6607  23.4500     0  S = Southampton
# 889              0      0            111369  30.0000  C148    C = Cherbourg
# 890              0      0            370376   7.7500     0   Q = Queenstown
#
# [891 rows x 11 columns]

# %%
dados['Embarked'].value_counts().plot(kind='bar', 
                                         title='Embarked')
plt.show()

# %%
dados['Pclass'].value_counts().plot(kind='bar', 
                                         title='Pclass')
plt.show()

# %%
data = dados['Survived']
data_height = data.value_counts()
bar_labels = ['0 = No', '1 = Yes']

# Creating a bar plot
plt.bar(bar_labels, data_height)

# Adding labels to the bars
for i in range(len(data_height)):
    plt.text(i, data_height[i], str(data_height[i]), ha='center', va='bottom')

plt.xlabel('Survived')
plt.ylabel('Count')
plt.title('Survival Distribution')
plt.show()

# %%
dados.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data = dados.Sex
data_height = data.value_counts()
bar_labels = ['Female', 'Male']

# Creating a bar plot
plt.bar(bar_labels, data_height)

# Adding labels to the bars
for i in range(len(data_height)):
    plt.text(i, data_height[i], str(data_height[i]), ha='center', va='bottom')

plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('The quantity of females and males in Titanic')
plt.show()
# Out:
# /var/folders/dz/0xtgsvld2wj69430hwkw47hm0000gn/T/ipykernel_30308/2795978184.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(i, data_height[i], str(data_height[i]), ha='center', va='bottom')

# %%
dados
# Out:
#              Survived  Pclass  \
# PassengerId
# 0                   0       3
# 1                   1       1
# 2                   1       3
# 3                   1       1
# 4                   0       3
# ...               ...     ...
# 886                 0       2
# 887                 1       1
# 888                 0       3
# 889                 1       1
# 890                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 0                                      Braund, Mr. Owen Harris    male  22.0
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                                       Heikkinen, Miss. Laina  female  26.0
# 3                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 886                                      Montvila, Rev. Juozas    male  27.0
# 887                               Graham, Miss. Margaret Edith  female  19.0
# 888                   Johnston, Miss. Catherine Helen "Carrie"  female   0.0
# 889                                      Behr, Mr. Karl Howell    male  26.0
# 890                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin         Embarked
# PassengerId
# 0                1      0         A/5 21171   7.2500     0  S = Southampton
# 1                1      0          PC 17599  71.2833   C85    C = Cherbourg
# 2                0      0  STON/O2. 3101282   7.9250     0  S = Southampton
# 3                1      0            113803  53.1000  C123  S = Southampton
# 4                0      0            373450   8.0500     0  S = Southampton
# ...            ...    ...               ...      ...   ...              ...
# 886              0      0            211536  13.0000     0  S = Southampton
# 887              0      0            112053  30.0000   B42  S = Southampton
# 888              1      2        W./C. 6607  23.4500     0  S = Southampton
# 889              0      0            111369  30.0000  C148    C = Cherbourg
# 890              0      0            370376   7.7500     0   Q = Queenstown
#
# [891 rows x 11 columns]

# %%
yes = dados['Survived'] == 1
no  = dados['Survived'] == 0

dados.loc[no, 'Survived'] = '0 = No'
dados.loc[yes, 'Survived'] = '1 = Yes'
# Out:
# /var/folders/dz/0xtgsvld2wj69430hwkw47hm0000gn/T/ipykernel_30308/2456065829.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0 = No' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dados.loc[no, 'Survived'] = '0 = No'

# %%
dados
# Out:
#             Survived  Pclass  \
# PassengerId
# 0             0 = No       3
# 1            1 = Yes       1
# 2            1 = Yes       3
# 3            1 = Yes       1
# 4             0 = No       3
# ...              ...     ...
# 886           0 = No       2
# 887          1 = Yes       1
# 888           0 = No       3
# 889          1 = Yes       1
# 890           0 = No       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 0                                      Braund, Mr. Owen Harris    male  22.0
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                                       Heikkinen, Miss. Laina  female  26.0
# 3                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 886                                      Montvila, Rev. Juozas    male  27.0
# 887                               Graham, Miss. Margaret Edith  female  19.0
# 888                   Johnston, Miss. Catherine Helen "Carrie"  female   0.0
# 889                                      Behr, Mr. Karl Howell    male  26.0
# 890                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin         Embarked
# PassengerId
# 0                1      0         A/5 21171   7.2500     0  S = Southampton
# 1                1      0          PC 17599  71.2833   C85    C = Cherbourg
# 2                0      0  STON/O2. 3101282   7.9250     0  S = Southampton
# 3                1      0            113803  53.1000  C123  S = Southampton
# 4                0      0            373450   8.0500     0  S = Southampton
# ...            ...    ...               ...      ...   ...              ...
# 886              0      0            211536  13.0000     0  S = Southampton
# 887              0      0            112053  30.0000   B42  S = Southampton
# 888              1      2        W./C. 6607  23.4500     0  S = Southampton
# 889              0      0            111369  30.0000  C148    C = Cherbourg
# 890              0      0            370376   7.7500     0   Q = Queenstown
#
# [891 rows x 11 columns]

# %%
first =  dados['Pclass'] == 1
second  = dados['Pclass'] == 2
third  = dados['Pclass'] == 3

dados.loc[first, 'Pclass'] = 'First class'
dados.loc[second, 'Pclass'] = 'Second class'
dados.loc[third, 'Pclass'] = 'Third class'
# Out:
# /var/folders/dz/0xtgsvld2wj69430hwkw47hm0000gn/T/ipykernel_30308/4049814742.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'First class' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dados.loc[first, 'Pclass'] = 'First class'

# %%
dados
# Out:
#             Survived        Pclass  \
# PassengerId
# 0             0 = No   Third class
# 1            1 = Yes   First class
# 2            1 = Yes   Third class
# 3            1 = Yes   First class
# 4             0 = No   Third class
# ...              ...           ...
# 886           0 = No  Second class
# 887          1 = Yes   First class
# 888           0 = No   Third class
# 889          1 = Yes   First class
# 890           0 = No   Third class
#
#                                                           Name     Sex   Age  \
# PassengerId
# 0                                      Braund, Mr. Owen Harris    male  22.0
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                                       Heikkinen, Miss. Laina  female  26.0
# 3                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 886                                      Montvila, Rev. Juozas    male  27.0
# 887                               Graham, Miss. Margaret Edith  female  19.0
# 888                   Johnston, Miss. Catherine Helen "Carrie"  female   0.0
# 889                                      Behr, Mr. Karl Howell    male  26.0
# 890                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin         Embarked
# PassengerId
# 0                1      0         A/5 21171   7.2500     0  S = Southampton
# 1                1      0          PC 17599  71.2833   C85    C = Cherbourg
# 2                0      0  STON/O2. 3101282   7.9250     0  S = Southampton
# 3                1      0            113803  53.1000  C123  S = Southampton
# 4                0      0            373450   8.0500     0  S = Southampton
# ...            ...    ...               ...      ...   ...              ...
# 886              0      0            211536  13.0000     0  S = Southampton
# 887              0      0            112053  30.0000   B42  S = Southampton
# 888              1      2        W./C. 6607  23.4500     0  S = Southampton
# 889              0      0            111369  30.0000  C148    C = Cherbourg
# 890              0      0            370376   7.7500     0   Q = Queenstown
#
# [891 rows x 11 columns]

# %%
dados_mean_fare = dados.Fare.mean().round(2)
dados_median_fare = dados.Fare.median().round(2)

# %%
dados['mean_fare'] = dados_mean_fare
dados['median_fare'] = dados_median_fare

# %%
dados
# Out:
#             Survived        Pclass  \
# PassengerId
# 0             0 = No   Third class
# 1            1 = Yes   First class
# 2            1 = Yes   Third class
# 3            1 = Yes   First class
# 4             0 = No   Third class
# ...              ...           ...
# 886           0 = No  Second class
# 887          1 = Yes   First class
# 888           0 = No   Third class
# 889          1 = Yes   First class
# 890           0 = No   Third class
#
#                                                           Name     Sex   Age  \
# PassengerId
# 0                                      Braund, Mr. Owen Harris    male  22.0
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                                       Heikkinen, Miss. Laina  female  26.0
# 3                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 886                                      Montvila, Rev. Juozas    male  27.0
# 887                               Graham, Miss. Margaret Edith  female  19.0
# 888                   Johnston, Miss. Catherine Helen "Carrie"  female   0.0
# 889                                      Behr, Mr. Karl Howell    male  26.0
# 890                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin         Embarked  \
# PassengerId
# 0                1      0         A/5 21171   7.2500     0  S = Southampton
# 1                1      0          PC 17599  71.2833   C85    C = Cherbourg
# 2                0      0  STON/O2. 3101282   7.9250     0  S = Southampton
# 3                1      0            113803  53.1000  C123  S = Southampton
# 4                0      0            373450   8.0500     0  S = Southampton
# ...            ...    ...               ...      ...   ...              ...
# 886              0      0            211536  13.0000     0  S = Southampton
# 887              0      0            112053  30.0000   B42  S = Southampton
# 888              1      2        W./C. 6607  23.4500     0  S = Southampton
# 889              0      0            111369  30.0000  C148    C = Cherbourg
# 890              0      0            370376   7.7500     0   Q = Queenstown
#
#              mean_fare  median_fare
# PassengerId
# 0                 32.2        14.45
# 1                 32.2        14.45
# 2                 32.2        14.45
# 3                 32.2        14.45
# 4                 32.2        14.45
# ...                ...          ...
# 886               32.2        14.45
# 887               32.2        14.45
# 888               32.2        14.45
# 889               32.2        14.45
# 890               32.2        14.45
#
# [891 rows x 13 columns]

# %%
dados.SibSp.value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
dados.Parch.value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
dados['SibSp'].value_counts().plot(kind='bar', 
                                         title='# of siblings / spouses aboard the Titanic')
plt.show()

# %%
dados['Parch'].value_counts().plot(kind='bar', 
                                         title='# of parents / children aboard the Titanic')
plt.show()

# %%
dados['Age'].value_counts()
# Out:
# Age
# 0.00     177
# 24.00     30
# 22.00     27
# 18.00     26
# 28.00     25
#         ...
# 36.50      1
# 55.50      1
# 0.92       1
# 23.50      1
# 74.00      1
# Name: count, Length: 89, dtype: int64

# %%
dados
# Out:
#             Survived        Pclass  \
# PassengerId
# 0             0 = No   Third class
# 1            1 = Yes   First class
# 2            1 = Yes   Third class
# 3            1 = Yes   First class
# 4             0 = No   Third class
# ...              ...           ...
# 886           0 = No  Second class
# 887          1 = Yes   First class
# 888           0 = No   Third class
# 889          1 = Yes   First class
# 890           0 = No   Third class
#
#                                                           Name     Sex   Age  \
# PassengerId
# 0                                      Braund, Mr. Owen Harris    male  22.0
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                                       Heikkinen, Miss. Laina  female  26.0
# 3                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 886                                      Montvila, Rev. Juozas    male  27.0
# 887                               Graham, Miss. Margaret Edith  female  19.0
# 888                   Johnston, Miss. Catherine Helen "Carrie"  female   0.0
# 889                                      Behr, Mr. Karl Howell    male  26.0
# 890                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin         Embarked  \
# PassengerId
# 0                1      0         A/5 21171   7.2500     0  S = Southampton
# 1                1      0          PC 17599  71.2833   C85    C = Cherbourg
# 2                0      0  STON/O2. 3101282   7.9250     0  S = Southampton
# 3                1      0            113803  53.1000  C123  S = Southampton
# 4                0      0            373450   8.0500     0  S = Southampton
# ...            ...    ...               ...      ...   ...              ...
# 886              0      0            211536  13.0000     0  S = Southampton
# 887              0      0            112053  30.0000   B42  S = Southampton
# 888              1      2        W./C. 6607  23.4500     0  S = Southampton
# 889              0      0            111369  30.0000  C148    C = Cherbourg
# 890              0      0            370376   7.7500     0   Q = Queenstown
#
#              mean_fare  median_fare
# PassengerId
# 0                 32.2        14.45
# 1                 32.2        14.45
# 2                 32.2        14.45
# 3                 32.2        14.45
# 4                 32.2        14.45
# ...                ...          ...
# 886               32.2        14.45
# 887               32.2        14.45
# 888               32.2        14.45
# 889               32.2        14.45
# 890               32.2        14.45
#
# [891 rows x 13 columns]
